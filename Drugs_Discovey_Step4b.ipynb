# %% [markdown]
# # Step 4b: Hydrogen Bond Donors - First Lipinski Rule
# Explanation Script: "Lipinski's Rule of Five helps predict if a molecule can be an oral drug. The first rule: hydrogen bond donors should be less than 5. H-bond donors are hydrogens attached to oxygen or nitrogen. Let's calculate this for common drugs using RDKit's Lipinski module."

# %%
from rdkit import Chem
from rdkit.Chem import Lipinski

# Chloroquine 
Chloroquine_smiles = "CCN(CC)CCCC(C)NC1=C2C=CC(=CC2=NC=C1)Cl"
mol_chl = Chem.MolFromSmiles(smiles)
hbd_chl = Lipinski.NumHDonors(mol_chl)
print(f"chloroquine H-bond donors: {hbd_chl}")

"CN(C)C(=N)N=C(N)N", # metformin
# Metformin 
metformin_smiles = "CN(C)C(=N)N=C(N)N"
mol_met = Chem.MolFromSmiles(metformin_smiles)
hbd_met = Lipinski.NumHDonors(mol_met)
print(f"Metformin H-bond donors: {hbd_met}")

# Ibuprofen
ibuprofen_smiles = "CC(C)CC1=CC=C(C=C1)C(C)C(=O)O"
mol_ibu = Chem.MolFromSmiles(ibuprofen_smiles)
hbd_ibu = Lipinski.NumHDonors(mol_ibu)
print(f"Ibuprofen H-bond donors: {hbd_ibu}")

# Pyrimethamine
pyrimethamine_smiles = "CCC1=C(C(=NC(=N1)N)N)C2=CC=C(C=C2)Cl"
mol_pyr = Chem.MolFromSmiles(pyrimethamine_smiles)
hbd_pyr = Lipinski.NumHDonors(mol_pyr)
print(f"pyrimethamine H-bond donors: {hbd_pyr}")

# Isoniazid 
isoniazid_smiles = "C1=CN=CC=C1C(=O)NN"
mol_iso = Chem.MolFromSmiles(isoniazid_smiles)
hbd_iso = Lipinski.NumHDonors(mol_iso)
print(f"Isoniazid H-bond donors: {hbd_iso}")
# Out:
# chloroquine H-bond donors: 1
# Metformin H-bond donors: 3
# Ibuprofen H-bond donors: 1
# pyrimethamine H-bond donors: 2
# Isoniazid H-bond donors: 2
