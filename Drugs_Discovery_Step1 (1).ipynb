# %% [markdown]
# # Drugs Discovery using Machine Learning with Love
# # Step 1: Python Basics – Lists and Loops with Drug Names
# Explanation Script: "Before we touch molecules, let's quickly review Python basics using drug names. We'll create a list of some drugs,and also list each drugs with its intended use and loop through them. Open a new Jupyter cell and type:"

# %%
# A list of drug names
drugs = ["urea","metformin","chloroquine","isoniazid","pyrimethamine", "salbutamol","aspirin","ibuprofen","caffeine", "propofol"]
drugs = ["urea for dry skin", "metformin for diabetes", "chloroquine for malaria", "isoniazid for tuberculosis", "caffeine to combat drowsiness","pyrimethamine for malaria","salbutamol for breathing","aspirin for pain","ibuprofen for anti-inflammatory ","propofol for anesthesia_in_surgery "]
# Loop through and print each one
for drug in drugs:
    print("Drug:", drug)

# Print the first drug
print("First drug:", drugs[0])
# Out:
# Drug: urea for dry skin
# Drug: metformin for diabetes
# Drug: chloroquine for malaria
# Drug: isoniazid for tuberculosis
# Drug: caffeine to combat drowsiness
# Drug: pyrimethamine for malaria
# Drug: salbutamol for breathing
# Drug: aspirin for pain
# Drug: ibuprofen for anti-inflammatory
# Drug: propofol for anesthesia_in_surgery
# First drug: urea for dry skin
