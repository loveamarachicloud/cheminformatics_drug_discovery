# %% [markdown]
# # Step 4g: Complete Lipinski Analysis
# Explanation Script: "Now let's combine all five properties into one table to see which molecules are truly drug-like according to Lipinski's rules."

# %%
from rdkit import Chem
from rdkit.Chem import Descriptors, Lipinski

drugs  = [ 
("metformin", "CN(C)C(=N)N=C(N)N"),
("chloroquine", "CCN(CC)CCCC(C)NC1=C2C=CC(=CC2=NC=C1)Cl"), 
("isoniazid", "C1=CN=CC=C1C(=O)NN"), 
("pyrimethamine", "CCC1=C(C(=NC(=N1)N)N)C2=CC=C(C=C2)Cl"),
("ibuprofen","CC(C)CC1=CC=C(C=C1)C(C)C(=O)O"),
]
print("Drug        MW    LogP  HBD  HBA  TPSA   Lipinski")
print("-" * 60)

for name, smiles in drugs:
    mol = Chem.MolFromSmiles(smiles)
    mw = Descriptors.MolWt(mol)
    logp = Descriptors.MolLogP(mol)
    hbd = Lipinski.NumHDonors(mol)
    hba = Lipinski.NumHAcceptors(mol)
    tpsa = Descriptors.TPSA(mol)
    
    violations = 0
    if mw >= 500: violations += 1
    if logp >= 5: violations += 1
    if hbd >= 5: violations += 1
    if hba >= 10: violations += 1
    
    status = "Pass" if violations == 0 else f"Fail ({violations} violations)"
    
    print(f"{name:10} {mw:5.0f} {logp:5.2f} {hbd:4} {hba:4} {tpsa:6.1f}   {status}")
# Out:
# Drug        MW    LogP  HBD  HBA  TPSA   Lipinski
# ------------------------------------------------------------
# metformin    129 -1.24    3    1   91.5   Pass
# chloroquine   320  4.81    1    3   28.2   Pass
# isoniazid    137 -0.31    2    3   68.0   Pass
# pyrimethamine   249  2.52    2    4   77.8   Pass
# ibuprofen    206  3.07    1    1   37.3   Pass

# %% [markdown]
# "We've completed a full Lipinski analysis. All these molecules pass all four rules. This is how pharmaceutical companies filter millions of compounds to find promising drug candidates. In the next step, we'll learn about molecular fingerprints for machine learning."
